# %%
import matplotlib.pyplot as plt
import seaborn as sns 

tips = sns.load_dataset("tips")
penguins = sns.load_dataset("penguins")

# %%
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df_heat = penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].corr()

fig = plt.figure(figsize = (16, 16))
gs = fig.add_gridspec(1, 1)
ax0 = fig.add_subplot(gs[0, 0])

sns.heatmap(df_heat, 
            ax = ax0, vmin = -0.5, vmax = 0.5, 
            annot = True, square = True, 
            cbar = True, cmap = 'rocket', 
            fmt = '.1g')
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style = 'whitegrid')

# %%
sns.catplot(data = penguins, kind = 'swarm')

# %%
sns.relplot(data = penguins, kind = 'scatter', x = 'flipper_length_mm', y = 'body_mass_g')
plt.savefig('images\savefigtestname.png', bbox_inches = 'tight')

# %%
sns.displot(data = penguins, kind = 'kde', x = 'bill_length_mm', hue = 'species', 
            rug = True, multiple = 'layer')

# %%
# Is there any relationship between 
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.catplot(data = penguins, x = 'species', y = 'bill_depth_mm', col = 'sex', row = 'island', 
        kind = 'bar')

# %%
ex = sns.load_dataset('exercise')
ex.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
sns.catplot(data = ex, x = 'time', y = 'pulse', hue = 'kind', kind = 'swarm', col = 'diet')
